# %%
import requests

# 인코딩 인증키와 디코딩 인증키 설정
encoding_auth_key = "%2Ft%2BeDkLF8Ol9wEFDAKwpWxgR0endz7sz%2BhU40mUPHFsrLuCXqs6BKjhelL4iVPmSdWlY4dkN36fJu%2BRK38Lcrg%3D%3D"
decoding_auth_key = "/t+eDkLF8Ol9wEFDAKwpWxgR0endz7sz+hU40mUPHFsrLuCXqs6BKjhelL4iVPmSdWlY4dkN36fJu+RK38Lcrg=="

# 요청 URL 설정
base_url = "http://apis.data.go.kr/4550000/GSAPI05/GS_GinsengFarm"
request_url = f"{base_url}?serviceKey={encoding_auth_key}"

# 요청 파라미터 설정 (필요한 정보에 따라 변경)
params = {
    "searchCondition": "string",  # 검색 조건
    "searchKeyword": "string",    # 검색 키워드
    "pageUnit": 10,               # 한 페이지에 표시할 항목 수
    "pageIndex": 1                # 페이지 번호
}

# 요청 보내기
response = requests.get(request_url, params=params)

# 응답 확인 및 처리
if response.status_code == 200:
    data = response.json()
    body = data.get("body", {})
    header = body.get("header", {})

    # 결과 메시지 출력
    result_msg = header.get("resultMsg", "")
    print(f"Result Message: {result_msg}")

    # 데이터 처리 (필요한 정보에 따라 변경)
    if header.get("resultCode") == "00":
        items = body.get("items", {}).get("item", [])
        if isinstance(items, list):
            for item in items:
                lGubun = item.get("lGubun", "")
                item_name = item.get("item", "")
                grp_name = item.get("grpNm", "")
                rprsv_name = item.get("rprsvNm", "")
                lotno_addr = item.get("lotnoAddr", "")
                cultivation_area = item.get("cultivationArea", 0)
                production_amount_plan = item.get("productionAmountPlan", 0)

                # 필요한 정보를 이용하여 원하는 처리 수행
                # 예: 출력, 저장 등
        elif isinstance(items, dict):
            # 하나의 항목만 반환되는 경우 처리
            lGubun = items.get("lGubun", "")
            item_name = items.get("item", "")
            grp_name = items.get("grpNm", "")
            rprsv_name = items.get("rprsvNm", "")
            lotno_addr = items.get("lotnoAddr", "")
            cultivation_area = items.get("cultivationArea", 0)
            production_amount_plan = items.get("productionAmountPlan", 0)

            # 필요한 정보를 이용하여 원하는 처리 수행
            # 예: 출력, 저장 등
    else:
        print("Error: Data not found.")

else:
    print(f"Error: Request failed with status code {response.status_code}")
    print(response.text)  # 서버에서 보내온 응답 메시지 출력
# Out:
# Result Message:
# Error: Data not found.

# %%
import requests

try:
    # 인터넷에 연결되어 있는지 확인하는 간단한 요청
    response = requests.get("https://www.google.com")
    if response.status_code == 200:
        print("인터넷 연결 확인됨")
    else:
        print("인터넷 연결 실패")
except requests.exceptions.RequestException as e:
    print("인터넷 연결 실패:", e)
# Out:
# 인터넷 연결 확인됨

# %%
import requests

# 요청 보내기
response = requests.get(request_url, params=params)

if response.status_code == 200:
    data = response.json()
    # 데이터 처리 로직 추가
else:
    print("HTTP 상태 코드:", response.status_code)
# Out:
# HTTP 상태 코드: 500

# %%
import requests

# API 기본 URL
base_url = "apis.data.go.kr/4550000/GSAPI08"

# 인증키 (디코딩 된 키를 사용)
api_key = "/t+eDkLF8Ol9wEFDAKwpWxgR0endz7sz+hU40mUPHFsrLuCXqs6BKjhelL4iVPmSdWlY4dkN36fJu+RK38Lcrg=="

# 요청 파라미터 설정
params = {
    # 필요한 요청 파라미터를 추가하세요.
    # 예: "year": 2023, "product_name": "인삼제품"
    # API 문서를 참조하여 필요한 파라미터를 설정하세요.
    # https://apis.data.go.kr/4550000/GSAPI08/doc/gsapi08/gsapi08.do
    "year": 2023,
    "product_name": "인삼제품"
}

# GET 요청 보내기
response = requests.get(f"https://{base_url}", params=params, headers={"Authorization": f"Bearer {api_key}"})

# 응답 확인
if response.status_code == 200:
    data = response.json()  # JSON 형태의 응답을 파싱합니다.
    # 데이터를 가지고 원하는 작업을 수행하세요.
    print(data)
else:
    print(f"요청이 실패하였습니다. 상태 코드: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:1092, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 if conn.is_closed:
# -> 1092     conn.connect()
#    1094 if not conn.is_verified:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connection.py:642, in HTTPSConnection.connect(self)
#     634     warnings.warn(
#     635         (
#     636             f"System time is way off (before {RECENT_DATE}). This will probably "
# ...

# %%
import requests
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

# Retry 설정 추가
retry_strategy = Retry(
    total=5,
    backoff_factor=0.1,
    status_forcelist=[429, 500, 502, 503, 504],
)

adapter = HTTPAdapter(max_retries=retry_strategy)
http = requests.Session()
http.mount("https://", adapter)

# API 호출
response = http.get("https://apis.data.go.kr/4550000/GSAPI08?year=2023&product_name=%EC%9D%B8%EC%82%BC%EC%A0%9C%ED%92%88")
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:1092, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 if conn.is_closed:
# -> 1092     conn.connect()
#    1094 if not conn.is_verified:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connection.py:642, in HTTPSConnection.connect(self)
#     634     warnings.warn(
#     635         (
#     636             f"System time is way off (before {RECENT_DATE}). This will probably "
# ...

# %%
import requests

# API 호출 (SSL 인증서 검사 무시)
response = requests.get("https://apis.data.go.kr/4550000/GSAPI08?year=2023&product_name=%EC%9D%B8%EC%82%BC%EC%A0%9C%ED%92%88", verify=False)
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:1092, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 if conn.is_closed:
# -> 1092     conn.connect()
#    1094 if not conn.is_verified:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connection.py:642, in HTTPSConnection.connect(self)
#     634     warnings.warn(
#     635         (
#     636             f"System time is way off (before {RECENT_DATE}). This will probably "
# ...

# %%
import requests

# TLS 1.2 사용 설정
session = requests.Session()
session.mount("https://", requests.adapters.HTTPAdapter(max_retries=3))
session.verify = False  # 인증서 검증 무시 (주의: 보안상 위험)

response = session.get("https://apis.data.go.kr/4550000/GSAPI08?year=2023&product_name=%EC%9D%B8%EC%82%BC%EC%A0%9C%ED%92%88")
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:1092, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 if conn.is_closed:
# -> 1092     conn.connect()
#    1094 if not conn.is_verified:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connection.py:642, in HTTPSConnection.connect(self)
#     634     warnings.warn(
#     635         (
#     636             f"System time is way off (before {RECENT_DATE}). This will probably "
# ...

# %%
import requests

# API 기본 URL
base_url = "apis.data.go.kr/4550000/GSAPI07"

# 인증키 (디코딩 된 키를 사용)
api_key = "/t+eDkLF8Ol9wEFDAKwpWxgR0endz7sz+hU40mUPHFsrLuCXqs6BKjhelL4iVPmSdWlY4dkN36fJu+RK38Lcrg=="

# 요청 파라미터 설정
params = {
    # 필요한 요청 파라미터를 추가하세요.
    # 예: "year": 2023, "location": "금산군"
    # API 문서를 참조하여 필요한 파라미터를 설정하세요.
    # https://apis.data.go.kr/4550000/GSAPI07/doc/gsapi07/gsapi07.do
    "year": 2023,
    "location": "금산군"
}

# GET 요청 보내기
response = requests.get(f"https://{base_url}", params=params, headers={"Authorization": f"Bearer {api_key}"})

# 응답 확인
if response.status_code == 200:
    data = response.json()  # JSON 형태의 응답을 파싱합니다.
    # 데이터를 가지고 원하는 작업을 수행하세요.
    print(data)
else:
    print(f"요청이 실패하였습니다. 상태 코드: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:1092, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 if conn.is_closed:
# -> 1092     conn.connect()
#    1094 if not conn.is_verified:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connection.py:642, in HTTPSConnection.connect(self)
#     634     warnings.warn(
#     635         (
#     636             f"System time is way off (before {RECENT_DATE}). This will probably "
# ...

# %%
import requests

# TLS 1.2 사용 설정
session = requests.Session()
session.mount("https://", requests.adapters.HTTPAdapter(max_retries=3))
session.verify = False  # 인증서 검증 무시 (주의: 보안상 위험)

response = session.get("https://apis.data.go.kr/4550000/GSAPI07?year=2023&location=%EA%B8%88%EC%82%B0%EA%B5%B0")
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:1092, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 if conn.is_closed:
# -> 1092     conn.connect()
#    1094 if not conn.is_verified:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connection.py:642, in HTTPSConnection.connect(self)
#     634     warnings.warn(
#     635         (
#     636             f"System time is way off (before {RECENT_DATE}). This will probably "
# ...

# %%
import requests
import ssl  # ssl 모듈 임포트

# TLS 1.0 사용 설정
session = requests.Session()
session.mount("https://", requests.adapters.HTTPAdapter(max_retries=3))
session.verify = False  # 인증서 검증 무시 (주의: 보안상 위험)
session.ssl_version = ssl.PROTOCOL_SSLv23  # SSL/TLS 버전 설정

response = session.get("https://apis.data.go.kr/4550000/GSAPI07?year=2023&location=%EA%B8%88%EC%82%B0%EA%B5%B0")
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:1092, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 if conn.is_closed:
# -> 1092     conn.connect()
#    1094 if not conn.is_verified:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connection.py:642, in HTTPSConnection.connect(self)
#     634     warnings.warn(
#     635         (
#     636             f"System time is way off (before {RECENT_DATE}). This will probably "
# ...

# %%
session.ssl_version = ssl.PROTOCOL_TLSv1_2  # TLS 1.2 사용 설정

# %%
import requests
import ssl

# TLS 1.2 사용 설정
session = requests.Session()
session.verify = True  # SSL 인증서 검증 활성화

# TLS 1.2 사용 설정
session.ssl_version = ssl.PROTOCOL_TLSv1_2

# API 요청 URL
url = "https://apis.data.go.kr/4550000/GSAPI07?year=2023&location=%EA%B8%88%EC%82%B0%EA%B5%B0"

try:
    response = session.get(url)
    response.raise_for_status()  # 요청이 실패하면 예외 발생
    # 이제 response 변수를 사용하여 데이터를 처리하실 수 있습니다.
    print(response.text)
except requests.exceptions.RequestException as e:
    print(f"오류 발생: {e}")
# Out:
# 오류 발생: HTTPSConnectionPool(host='apis.data.go.kr', port=443): Max retries exceeded with url: /4550000/GSAPI07?year=2023&location=%EA%B8%88%EC%82%B0%EA%B5%B0 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_ILLEGAL_PARAMETER] sslv3 alert illegal parameter (_ssl.c:1006)')))

# %%
session.ssl_version = ssl.PROTOCOL_TLSv1_1

# %%
import requests
import ssl

# TLS 1.2 사용 설정
session = requests.Session()
session.verify = True  # SSL 인증서 검증 활성화
session.ssl_version = ssl.PROTOCOL_TLSv1_2  # TLS 1.2 사용 설정

# API 요청 URL
url = "https://apis.data.go.kr/4550000/GSAPI07?year=2023&location=%EA%B8%88%EC%82%B0%EA%B5%B0"

try:
    response = session.get(url)
    response.raise_for_status()  # 요청이 실패하면 예외 발생
    # 이제 response 변수를 사용하여 데이터를 처리하실 수 있습니다.
    print(response.text)
except requests.exceptions.RequestException as e:
    print(f"오류 발생: {e}")
# Out:
# 오류 발생: HTTPSConnectionPool(host='apis.data.go.kr', port=443): Max retries exceeded with url: /4550000/GSAPI07?year=2023&location=%EA%B8%88%EC%82%B0%EA%B5%B0 (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_ILLEGAL_PARAMETER] sslv3 alert illegal parameter (_ssl.c:1006)')))
