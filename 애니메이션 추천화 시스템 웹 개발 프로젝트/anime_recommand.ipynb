# %%
import pandas as pd

df1 = pd.read_csv("/Users/raekkkky/Desktop/DNA/[24 1학기] 🏆승승장구/10주차/data/anime.csv")
df2 = pd.read_csv("/Users/raekkkky/Desktop/DNA/[24 1학기] 🏆승승장구/10주차/data/rating.csv")

# %%
df1.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
df2.head()
# Out:
#    user_id  anime_id  rating
# 0        1        20      -1
# 1        1        24      -1
# 2        1        79      -1
# 3        1       226      -1
# 4        1       241      -1

# %%
df2.value_counts()
# Out:
# user_id  anime_id  rating
# 42653    16498      8        2
# 1        20        -1        1
# 49543    370        8        1
#          430        9        1
#          421        3        1
#                             ..
# 24617    6347       9        1
#          6324       8        1
#          6205       7        1
#          6201       7        1
# 73516    8074       9        1
# Length: 7813736, dtype: int64

# %%
df2[df2['rating'] == -1]
# Out:
#          user_id  anime_id  rating
# 0              1        20      -1
# 1              1        24      -1
# 2              1        79      -1
# 3              1       226      -1
# 4              1       241      -1
# ...          ...       ...     ...
# 7813628    73515      2385      -1
# 7813629    73515      2386      -1
# 7813631    73515      2490      -1
# 7813635    73515      2680      -1
# 7813668    73515      5252      -1
#
# [1476496 rows x 3 columns]

# %%
df2.shape
# Out:
# (7813737, 3)
